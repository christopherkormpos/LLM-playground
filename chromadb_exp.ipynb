# %%
import chromadb

# %%
chroma_client = chromadb.Client()

# %%
collection = chroma_client.create_collection(name="my_collection")

# %%
collection.add(
    documents=[
        "This is a document about pineapple",
        "This is a document about oranges",
        "This is a document that says about tomatoes",
        "Pizza is the best available food here",
        "One of the best parts of the Greek cuisine is the souvlaki"
    ],
    ids=["id1", "id2","id3","id4","id5"]
)
# Out:
# /root/.cache/chroma/onnx_models/all-MiniLM-L6-v2/onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:11<00:00, 7.51MiB/s]

# %%
results = collection.query(
    query_texts=["This is a query document about Hawaii"],
    n_results=3 
)
print(results)
# Out:
# {'ids': [['id1', 'id2', 'id3']], 'embeddings': None, 'documents': [['This is a document about pineapple', 'This is a document about oranges', 'This is a document that says about tomatoes']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None, None]], 'distances': [[1.0404009819030762, 1.2430799007415771, 1.3180011510849]]}
